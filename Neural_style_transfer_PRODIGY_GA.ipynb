# %% [markdown]
# <a href="https://colab.research.google.com/github/28Mahi/Neural_style_transfer_PRODIGY_GA-Project_5-/blob/main/Neural_style_transfer_PRODIGY_GA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the Dependencies

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %% [markdown]
# # Preprocess Image and Load

# %%
def load_image(img_path):
  img = tf.io.read_file(img_path)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)
  img = img[tf.newaxis, :]
  return img

# %%
content_image = load_image('/Screenshot 2023-11-12 164138.png')
style_image = load_image('/Screenshot (9).png')

# %% [markdown]
# # Visualize Output

# %%
plt.imshow(np.squeeze(content_image))
plt.title("Content Image")
plt.show()

# %%
plt.imshow(np.squeeze(style_image))
plt.title("Style Image")
plt.show()

# %% [markdown]
# # Output Image

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
plt.imshow(np.squeeze(stylized_image))
plt.title("Stylized Image")
plt.show()
